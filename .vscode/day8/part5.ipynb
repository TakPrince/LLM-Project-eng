# %% [markdown]
# # The Price is Right
#
# The final step is to build a User Interface
#
# We will use more advanced aspects of Gradio - building piece by piece.

# %%
import gradio as gr
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal

# %%
# Updated to change from height to max_height due to change in Gradio v5
# With much thanks to student Ed B. for raising this

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])

ui.launch(inbrowser=True)
# Out:
# /home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/components/dataframe.py:191: UserWarning: The `col_count` parameter is deprecated and will be removed. Please use `column_count` instead.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
agent_framework = DealAgentFramework()
agent_framework.init_agents_as_needed()

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    def do_select(opportunities, selected_index: gr.SelectData):
        row = selected_index.index[0]
        opportunity = opportunities[row]
        agent_framework.planner.messenger.alert(opportunity)

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])
    opportunities_dataframe.select(do_select, inputs=[opportunities], outputs=[])

ui.launch(inbrowser=True)
# Out:
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with Groq
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] Use pytorch device_name: cpu
# [2026-01-16 22:27:51 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-01-16 22:27:55 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-01-16 22:27:55 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-01-16 22:27:57 +0530] [Agents] [INFO] Neural Network is using cpu
# [2026-01-16 22:27:58 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-01-16 22:27:58 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-01-16 22:27:58 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-01-16 22:27:58 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-01-16 22:27:58 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-01-16 22:27:58 +0530] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# /home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/components/dataframe.py:191: UserWarning: The `col_count` parameter is deprecated and will be removed. Please use `column_count` instead.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Time for the code
#
# And now we'll move to the price_is_right.py code

# %%
# Reset memory back to 2 deals discovered in the past

from deal_agent_framework import DealAgentFramework
DealAgentFramework.reset_memory()

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %% [markdown]
# # Running the final product
#
# ## Just hit shift + enter in the next cell, and let the deals flow in!!

# %%
# !uv run price_is_right.py
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with Groq
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] Use pytorch device_name: cpu
# [2026-01-16 22:28:20 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-01-16 22:28:24 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-01-16 22:28:24 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-01-16 22:28:26 +0530] [Agents] [INFO] Neural Network is using cpu
# [2026-01-16 22:28:27 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-01-16 22:28:27 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-01-16 22:28:27 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-01-16 22:28:27 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-01-16 22:28:27 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-01-16 22:28:27 +0530] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-01-16 22:28:27 +0530] [Agents] [INFO] Kicking off Planning Agent
# [2026-01-16 22:28:27 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-01-16 22:28:27 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-01-16 22:29:30 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 30 deals not already scraped
# [2026-01-16 22:29:30 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling Groq
# 22:29:32 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:29:53 - LiteLLM:INFO: utils.py:1575 - Wrapper: Completed Call, calling success_handler
# /home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/pydantic/main.py:464: UserWarning:
#
# Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [field_name='message', input_value=Message(content='### Syst... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [field_name='choices', input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  6.12it/s]
# 22:30:32 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:30:45 - LiteLLM:INFO: utils.py:1575 - Wrapper: Completed Call, calling success_handler
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  6.27it/s]
# 22:30:47 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:30:59 - LiteLLM:INFO: utils.py:1575 - Wrapper: Completed Call, calling success_handler
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  9.34it/s]
# 22:31:00 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:31:12 - LiteLLM:INFO: utils.py:1575 - Wrapper: Completed Call, calling success_handler
# /home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/pydantic/main.py:464: UserWarning:
#
# Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 6: Expected `Message` - serialized value may not be as expected [field_name='message', input_value=Message(content='### Prod... reasoning_content=None), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [field_name='choices', input_value=Choices(finish_reason='st...reasoning_content=None)), input_type=Choices])
#
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  6.94it/s]
# 22:31:13 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= llama3.2; provider = ollama
# 22:31:25 - LiteLLM:INFO: utils.py:1575 - Wrapper: Completed Call, calling success_handler
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 11.85it/s]
# 22:31:58 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
# 22:32:00 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
# 22:32:00 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
# 22:32:00 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
# 22:32:04 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
# 22:32:05 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
# 22:32:05 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
# 22:32:08 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
# 22:32:13 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
# 22:32:13 - LiteLLM:INFO: utils.py:3749 -
# LiteLLM completion() model= claude-sonnet-4-5; provider = anthropic
# Traceback (most recent call last):
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 2147, in process_api
#     result = await self.call_function(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/blocks.py", line 1629, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/gradio/utils.py", line 1034, in wrapper
#     response = f(*args, **kwargs)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/price_is_right.py", line 139, in do_select
#     self.get_agent_framework().planner.messenger.notify(
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 70, in notify
#     text = self.craft_message(description, deal_price, estimated_true_value)
#   File "/home/asus/Desktop/LLMProject/.vscode/day8/agents/messaging_agent.py", line 57, in craft_message
#     response = completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1653, in wrapper
#     raise e
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/utils.py", line 1517, in wrapper
#     result = original_function(*args, **kwargs)
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 4159, in completion
#     raise exception_type(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/main.py", line 2619, in completion
#     response = anthropic_chat_completions.completion(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/chat/handler.py", line 322, in completion
#     headers = AnthropicConfig().validate_environment(
#   File "/home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/litellm/llms/anthropic/common_utils.py", line 376, in validate_environment
#     raise litellm.AuthenticationError(
# litellm.exceptions.AuthenticationError: litellm.AuthenticationError: Missing Anthropic API Key - A call is being made to anthropic but no key is set either in the environment variables or via params. Please set `ANTHROPIC_API_KEY` in your environment vars
