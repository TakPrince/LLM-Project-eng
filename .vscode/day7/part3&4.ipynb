# %% [markdown]
# # Day 7 Part 3 and 4
#
# Fine-tune an open-source model to Predict Product Prices
#
# Please see this notebook in Google Colab:
#
# https://colab.research.google.com/drive/1gVhrCe0NTN0ysDZxXBgW6w32uDMMOq43?usp=sharing
