# %% [markdown]
# # Day 7 Part 1
#
# # "THE PRICE IS RIGHT" Capstone Project
#
# fine tune an open-source model!
#
# A model that can estimate how much something costs, from its description.
#
# # Order of play
#
# Prat 1: QLoRA
# Prat 2: Prompt Data and Base Model
# Prat 3: Train Part 1
# Prat 4: Train Part 2
# Prat 5: Eval

# %% [markdown]
# Please see this notebook in Google Colab:
#
# https://colab.research.google.com/drive/1RGRGHKqrHqpjPEYJ6WZMsG79eLUBGd4a?usp=sharing
