# %% [markdown]
# # RAG
#
# ## Evaluation!
#
# Keep in mind how you would evaluate RAG for your business
# This is such an important part of building an accurate and reliable RAG pipeline. And it's applicable to many aspects of solving business problems with LLMs. People are often focused on RAG architecture and RAG frameworks for their business. But even more important: evaluations!

# %%
from evaluation import test

# %%
tests = test.load_tests()

# %%
len(tests)
# Out:
# 150

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# Who won the prestigious IIOTY award in 2023?
# direct_fact
# Maxine Thompson won the prestigious Insurellm Innovator of the Year (IIOTY) award in 2023.
# ['Maxine', 'Thompson', 'IIOTY']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'direct_fact': 70,
#          'temporal': 20,
#          'spanning': 20,
#          'comparative': 10,
#          'numerical': 10,
#          'relationship': 10,
#          'holistic': 10})

# %%
from evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=0.16666666666666666, ndcg=0.29420493957109245, keywords_found=2, total_keywords=3, keyword_coverage=66.66666666666666)

# %%
eval, answer, chunks = evaluate_answer(example)
# Out:
# /home/asus/anaconda3/envs/ai_brochure_builder/lib/python3.10/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected 10 fields but got 5: Expected `Message` - serialized value may not be as expected [field_name='message', input_value=Message(content='{"accura...nNow produce JSON.\n\n'), input_type=Message])
#   PydanticSerializationUnexpectedValue(Expected `StreamingChoices` - serialized value may not be as expected [field_name='choices', input_value=Choices(finish_reason='st...Now produce JSON.\n\n')), input_type=Choices])
#   return self.__pydantic_serializer__.to_python(

# %%
eval
# Out:
# AnswerEval(feedback='The answer correctly identifies Maxine as the 2023 IIOTY winner, matching the core fact. However, it omits the surname "Thompson," which is present in the reference, so it is not fully accurate or complete. It also adds extra details about her contributions, which are not required and slightly reduce relevance. Overall, the response is mostly correct but missing a key piece of information and includes unnecessary elaboration.', accuracy=4.0, completeness=4.0, relevance=4.0)

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly identifies Maxine as the 2023 IIOTY winner, matching the core fact. However, it omits the surname "Thompson," which is present in the reference, so it is not fully accurate or complete. It also adds extra details about her contributions, which are not required and slightly reduce relevance. Overall, the response is mostly correct but missing a key piece of information and includes unnecessary elaboration.
# 4.0
# 4.0
# 4.0
